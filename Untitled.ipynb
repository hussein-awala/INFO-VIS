# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('tsv/products_countries.tsv','\t')

# %%
data.groupby('country').count()
# Out:
#                                      code
# country
# albania                                22
# algeria                               106
# andorra                                 9
# angola                                  1
# anguilla                                1
# argentina                              37
# armenia                                 7
# aruba                                   2
# australia                            1297
# austria                               403
# azerbaijan                             13
# bahrain                                 1
# bangladesh                              3
# belarus                                 2
# belgium                              4013
# benin                                   2
# bosnia-and-herzegovina                 15
# brazil                                 94
# british-indian-ocean-territory          1
# bulgaria                               31
# burkina-faso                           22
# ...

# %%
countries=pd.read_csv('tsv/countries.tsv','\t')

# %%
del countries['Unnamed: 3']
del countries['population']

# %%
countries.to_csv('countries_code.tsv')

# %%
countries['population'] = np.random.randint(1, 2000000000, countries.shape[0])

# %%
countries.to_csv('tsv/test.tsv',sep='\t')

# %%
additives=pd.read_csv('tsv/products_additives.tsv','\t')

# %%
country_products=pd.read_csv('tsv/products_countries.tsv','\t')

# %%
additives.head()
# Out:
#             code additive
# 0  0000000005470     e326
# 1  0000000005470    e262i
# 2  0000000005470    e14xx
# 3  0000000005470     e262
# 4  0000000020114     e422

# %%
country_products.head()
# Out:
#             code country
# 0  0000000001281  france
# 1  0000000001885  france
# 2  0000000005241  france
# 3  0000000005470  france
# 4  0000000005661  france

# %%
d=country_products.merge(additives,left_on='code',right_on='code',how='inner')

# %%
d.head()
# Out:
#             code country additive
# 0  0000000005470  france     e326
# 1  0000000005470  france    e262i
# 2  0000000005470  france    e14xx
# 3  0000000005470  france     e262
# 4  0000000020114  france     e422

# %%
d1=country_products.groupby('country').count()
d1.columns=['nbOfProduct']

# %%
d2=d.loc[:,['country','code']].groupby('country')[['code']].nunique()
d2.columns=['nbOfAdditive']

# %%
d3=d1.merge(d2,left_index=True,right_index=True,how='left').fillna(0)

# %%
d3.head()
# Out:
#           nbOfProduct  nbOfAdditive
# country
# albania            22           3.0
# algeria           106          42.0
# andorra             9           2.0
# angola              1           0.0
# anguilla            1           0.0

# %%
d1.head()
# Out:
#           nbOfProduct
# country
# albania            22
# algeria           106
# andorra             9
# angola              1
# anguilla            1

# %%
d3.to_csv('tsv/dataset.tsv','\t')

# %%
countries=pd.read_csv('tsv/countries_code.tsv')
del countries['Unnamed: 0']

# %%
countries.head()
# Out:
#     id           name
# 0  CHN          China
# 1  IND          India
# 2  USA  United States
# 3  IDN      Indonesia
# 4  BRA         Brazil

# %%
d3.reset_index(inplace=True)
d3.head()
# Out:
#     country  nbOfProduct  nbOfAdditive
# 0   albania           22           3.0
# 1   algeria          106          42.0
# 2   andorra            9           2.0
# 3    angola            1           0.0
# 4  anguilla            1           0.0

# %%
countries['c']=countries['name'].str.lower()

# %%
countries.head()
# Out:
#     id           name              c
# 0  CHN          China          china
# 1  IND          India          india
# 2  USA  United States  united states
# 3  IDN      Indonesia      indonesia
# 4  BRA         Brazil         brazil

# %%
dd=countries.merge(d3,left_on='c',right_on='country',how='left')
del dd['c']
del dd['country']

# %%
d3.sort_values(by=['nbOfProduct'],ascending=False).head(20)
# Out:
#               country  nbOfProduct  nbOfAdditive
# 50             france       145747       62668.0
# 55            germany        11431        3482.0
# 139             spain         5620        2166.0
# 144       switzerland         5558        2497.0
# 14            belgium         4013        1797.0
# 155     united-states         3903        1907.0
# 154    united-kingdom         3805        1408.0
# 96             mexico         2615        1550.0
# 73              italy         1325         394.0
# 8           australia         1297         379.0
# 124            russia         1263         161.0
# 143            sweden          994         505.0
# 23             canada          829         389.0
# 117          portugal          683         320.0
# 104       netherlands          673         261.0
# 131            serbia          540         194.0
# 9             austria          403         129.0
# 71            ireland          329         167.0
# ...

# %%
d3['country']=d3['country'].str.replace('-',' ')

# %%
d3.head(20)
# Out:
#                            country  nbOfProduct  nbOfAdditive
# 0                          albania           22           3.0
# 1                          algeria          106          42.0
# 2                          andorra            9           2.0
# 3                           angola            1           0.0
# 4                         anguilla            1           0.0
# 5                        argentina           37          16.0
# 6                          armenia            7           0.0
# 7                            aruba            2           0.0
# 8                        australia         1297         379.0
# 9                          austria          403         129.0
# 10                      azerbaijan           13           0.0
# 11                         bahrain            1           0.0
# 12                      bangladesh            3           2.0
# 13                         belarus            2           1.0
# ...

# %%
dd.to_csv('tsv/final_with_nan.tsv','\t')

# %%
dd.dropna().to_csv('tsv/final_without_nan.tsv','\t')

# %%
d3.sort_values(by=['nbOfProduct'],ascending=False).head(20)
# Out:
#               country  nbOfProduct  nbOfAdditive
# 50             france       145747       62668.0
# 55            germany        11431        3482.0
# 139             spain         5620        2166.0
# 144       switzerland         5558        2497.0
# 14            belgium         4013        1797.0
# 155     united states         3903        1907.0
# 154    united kingdom         3805        1408.0
# 96             mexico         2615        1550.0
# 73              italy         1325         394.0
# 8           australia         1297         379.0
# 124            russia         1263         161.0
# 143            sweden          994         505.0
# 23             canada          829         389.0
# 117          portugal          683         320.0
# 104       netherlands          673         261.0
# 131            serbia          540         194.0
# 9             austria          403         129.0
# 71            ireland          329         167.0
# ...
